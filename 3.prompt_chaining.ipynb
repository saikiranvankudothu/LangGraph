# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from dotenv import load_dotenv
import os
import google.generativeai as genai

# %%
load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
model = genai.GenerativeModel('models/gemini-2.0-flash')

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState)->BlogState:
    # fetch the title
    title = state['title']
    # call llm gen outline
    prompt = f'Generate a detail outline for a blog on the  topic - {title}'
    response = model.generate_content(prompt)
    # update state
    state['outline'] = response.text
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title = state['title']
    outline = state['outline']
    prompt = f"write a detailed blog on the tile {title} using the following outline \n {outline}"
    response = model.generate_content(prompt)
    state['content'] = response.text
    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

# edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initial_state = {
    'title': 'Rise of AI in India',
    'outline': '',
    'content': ''
}

final_state = workflow.invoke(initial_state)
print(final_state["content"])
# Out:
# ## Blog: Rise of AI in India: Opportunities, Challenges, and the Road Ahead
#
# **I. Introduction**
#
# Did you know that India's AI market is projected to reach a staggering $15.7 billion by 2026? This rapid growth underscores the transformative potential of Artificial Intelligence in reshaping the Indian economy and society. But what exactly is AI? Simply put, AI is the ability of a computer or machine to mimic human intelligence – learning, problem-solving, and decision-making. It's no longer a futuristic fantasy but a tangible reality rapidly permeating various aspects of our lives. This blog will delve into the burgeoning AI landscape in India, highlighting its key opportunities, addressing the challenges it faces, and outlining the path forward for sustained growth and development.
#
# **II. The Booming AI Landscape in India**
#
# India is experiencing an AI revolution. The market is projected to reach $15.7 billion by 2026, according to a report by Mordor Intelligence, showcasing a compound annual growth rate (CAGR) of over 30%. This growth is fueled by a combination of factors, including government initiatives, increasing investment, and the growing availability of data. Compared to global trends, India's AI adoption is catching up quickly, driven by its unique strengths and requirements.
#
# The Indian government is actively promoting AI adoption through initiatives like NITI Aayog's National Strategy for AI, which outlines a roadmap for AI development and deployment across various sectors. The government is also investing heavily in AI research and development, offering funding opportunities and incentives to startups and research institutions through programs like the AI Mission. Furthermore, significant emphasis is placed on skill development initiatives aimed at creating a pool of qualified AI professionals.
#
# Venture capital investment in Indian AI startups has been steadily increasing. In 2022 alone, Indian AI startups raised over $3.2 billion, according to a report by Tracxn. Prominent AI companies and startups like Fractal Analytics, Tata Elxsi, and SenseHawk have received substantial funding, attracting attention from both domestic and foreign investors. Foreign investment plays a crucial role in driving AI innovation in India, bringing in expertise, technology, and capital.
#
# **III. Key Sectors Driving AI Adoption in India**
#
# AI is rapidly transforming various sectors in India:
#
# *   **Healthcare:** AI-powered diagnostics are revolutionizing healthcare by enabling faster and more accurate disease detection. Companies like Niramai are using AI for early breast cancer screening. AI is also accelerating drug discovery, enabling personalized medicine through genetic analysis and tailored treatment plans. Remote patient monitoring and telemedicine solutions, powered by AI, are improving access to healthcare in remote and underserved areas. Successful AI implementations can be seen in institutions like Apollo Hospitals, which are using AI for predictive analytics and personalized care.
#
# *   **Agriculture:** Precision agriculture leverages AI for crop monitoring, yield prediction, and resource optimization. AI algorithms analyze satellite imagery and sensor data to determine optimal irrigation levels, fertilizer application, and pest control strategies. Companies like Cropin use AI to provide farmers with actionable insights, leading to increased productivity and income. AI-powered solutions are also helping farmers detect pests and diseases early, preventing crop losses and reducing the need for pesticides.
#
# *   **Finance:** AI is playing a vital role in fraud detection, risk assessment, and credit scoring. Banks and financial institutions are using AI algorithms to identify suspicious transactions and prevent fraudulent activities. AI-powered chatbots and virtual assistants are enhancing customer service, providing instant support and personalized recommendations. Algorithmic trading and investment management leverage AI to automate trading decisions and optimize investment portfolios. Fintech companies like Paytm and PhonePe are leveraging AI for risk assessment and customer service.
#
# *   **Manufacturing:** AI-powered robotics and automation are transforming factories, increasing efficiency and reducing costs. Predictive maintenance uses AI to anticipate equipment failures, minimizing downtime and optimizing maintenance schedules. Quality control is improved through AI-powered image recognition and anomaly detection. AI is also optimizing supply chain management, improving logistics and reducing transportation costs.
#
# *   **E-commerce:** Personalized recommendations and targeted advertising powered by AI are driving sales and improving customer engagement. E-commerce giants like Flipkart and Amazon are using AI to personalize the shopping experience for each user. AI-powered chatbots are providing instant customer support, answering queries and resolving issues efficiently. AI is also crucial for fraud prevention and security, protecting online transactions and preventing identity theft.
#
# **IV. Challenges to AI Adoption in India**
#
# Despite its immense potential, AI adoption in India faces several challenges:
#
# *   **Lack of Skilled Talent:** A significant shortage of qualified AI professionals, including data scientists, machine learning engineers, and AI researchers, hinders progress. Upskilling and reskilling initiatives are crucial to bridge the talent gap. There is a need for more comprehensive AI education and training programs at all levels of the education system, from schools to universities.
#
# *   **Data Availability and Quality:** Challenges related to data access, standardization, and privacy are significant obstacles. Many organizations struggle to access the data they need to train AI models. Data standardization is crucial to ensure that data from different sources can be integrated and analyzed effectively. Robust data governance frameworks are needed to protect data privacy and ensure ethical data usage.
#
# *   **Infrastructure Limitations:** Inadequate computing infrastructure and internet connectivity in certain areas limit the deployment of AI solutions. Investment in cloud computing and high-performance computing resources is essential. Addressing the digital divide is crucial to ensure that all segments of society can benefit from AI.
#
# *   **Ethical Concerns and Regulatory Framework:** Addressing bias in AI algorithms and ensuring fairness are critical concerns. Data privacy and security are paramount, especially in sensitive applications such as healthcare and finance. Clear ethical guidelines and regulatory frameworks are needed to govern AI development and deployment, ensuring responsible and ethical AI practices.
#
# *   **Cost of Implementation:** The high upfront cost of AI solutions can be a barrier for small and medium-sized enterprises (SMEs). Exploring affordable AI solutions and fostering innovation in cost-effective AI technologies is essential to democratize access to AI.
#
# **V. The Road Ahead: Strategies for Sustainable AI Growth in India**
#
# To ensure sustainable AI growth in India, the following strategies are crucial:
#
# *   **Strengthening AI Education and Skill Development:** Promote AI education at all levels, from schools to vocational training programs. Encourage collaboration between academia and industry to align training programs with industry needs. Support online learning platforms and bootcamps for AI skills development.
#
# *   **Fostering Innovation and Entrepreneurship:** Provide funding and mentorship to AI startups. Encourage open-source AI development and collaboration. Promote research and development in cutting-edge AI technologies, such as explainable AI and federated learning.
#
# *   **Building a Robust Data Ecosystem:** Develop data governance frameworks that balance data privacy with data accessibility. Invest in data infrastructure and data standardization initiatives. Encourage data sharing and collaboration between organizations, while ensuring data security and privacy.
#
# *   **Developing Ethical Guidelines and Regulatory Frameworks:** Establish clear ethical principles for AI development and deployment, addressing issues such as bias, fairness, and accountability. Develop regulatory frameworks that address data privacy, algorithmic bias, and the potential for misuse of AI. Promote public awareness and understanding of AI ethics.
#
# *   **Prioritizing AI for Social Impact:** Focus on developing AI solutions that address pressing social challenges such as poverty, healthcare, and education. Ensure that AI technologies are accessible and beneficial to all segments of society, particularly those who are most vulnerable.
#
# **VI. Conclusion**
#
# The rise of AI in India presents a transformative opportunity for economic growth, social development, and global competitiveness. While challenges related to talent, data, infrastructure, ethics, and cost exist, strategic investments in education, innovation, data governance, and ethical frameworks can pave the way for sustainable and inclusive AI growth. By embracing responsible AI development and deployment, India can unlock the full potential of AI to create a brighter future for all its citizens. Stay informed about AI advancements in India and explore opportunities to contribute to this exciting technological revolution!

# %%
print(final_state["outline"])
# Out:
# ## Blog Outline: Rise of AI in India: Opportunities, Challenges, and the Road Ahead
#
# **I. Introduction (Engage the Reader - ~100 words)**
#
# *   **Hook:** Start with a compelling statistic or anecdote illustrating the growing importance of AI in India (e.g., projected AI market size, a successful AI implementation in a local business, etc.).
# *   **Briefly define AI:**  In simple terms, explain what Artificial Intelligence is and why it's relevant to the modern world.
# *   **Thesis Statement:**  The blog will explore the burgeoning AI landscape in India, highlighting its key opportunities, addressing the challenges it faces, and outlining the path forward for sustained growth and development.
#
# **II. The Booming AI Landscape in India (Highlighting the Growth - ~300 words)**
#
# *   **Market Size and Growth:**
#     *   Present key statistics and projections related to the growth of the AI market in India (mention reports from NASSCOM, government agencies, or market research firms).
#     *   Quantify the market value and anticipated growth rate.
#     *   Compare it to global trends (briefly).
# *   **Government Initiatives & Policies:**
#     *   Discuss key government programs and policies promoting AI adoption (e.g., NITI Aayog's National Strategy for AI, AI Mission).
#     *   Highlight funding opportunities and incentives for AI research and development.
#     *   Mention initiatives aimed at skill development in AI.
# *   **Investment Trends:**
#     *   Analyze venture capital investment in Indian AI startups.
#     *   Highlight prominent AI companies and startups that have received funding.
#     *   Discuss the role of foreign investment in driving AI innovation.
#
# **III. Key Sectors Driving AI Adoption in India (Showcasing Applications - ~300 words)**
#
# *   **Healthcare:**
#     *   AI-powered diagnostics, drug discovery, and personalized medicine.
#     *   Remote patient monitoring and telemedicine solutions.
#     *   Examples of successful AI implementations in Indian healthcare institutions.
# *   **Agriculture:**
#     *   Precision agriculture using AI for crop monitoring, yield prediction, and resource optimization.
#     *   AI-powered solutions for pest control and disease detection.
#     *   Impact on farmer productivity and income.
# *   **Finance:**
#     *   AI in fraud detection, risk assessment, and credit scoring.
#     *   Chatbots and virtual assistants for customer service.
#     *   Algorithmic trading and investment management.
# *   **Manufacturing:**
#     *   AI-powered robotics and automation in factories.
#     *   Predictive maintenance and quality control.
#     *   Optimization of supply chain management.
# *   **E-commerce:**
#     *   Personalized recommendations and targeted advertising.
#     *   AI-powered chatbots for customer support.
#     *   Fraud prevention and security.
#
# **IV. Challenges to AI Adoption in India (Addressing the Roadblocks - ~300 words)**
#
# *   **Lack of Skilled Talent:**
#     *   Shortage of qualified AI professionals (data scientists, machine learning engineers, AI researchers).
#     *   Need for upskilling and reskilling initiatives to bridge the talent gap.
#     *   Emphasis on AI education and training programs.
# *   **Data Availability and Quality:**
#     *   Challenges related to data access, standardization, and privacy.
#     *   Need for robust data governance frameworks.
#     *   Importance of building high-quality datasets for AI model training.
# *   **Infrastructure Limitations:**
#     *   Inadequate computing infrastructure and internet connectivity in certain areas.
#     *   Need for investment in cloud computing and high-performance computing resources.
#     *   Addressing the digital divide.
# *   **Ethical Concerns and Regulatory Framework:**
#     *   Addressing bias in AI algorithms and ensuring fairness.
#     *   Data privacy and security concerns related to AI applications.
#     *   Need for clear ethical guidelines and regulatory frameworks for AI development and deployment.
# *   **Cost of Implementation:**
#     *   The high upfront cost of AI solutions can be a barrier for small and medium-sized enterprises (SMEs).
#     *   Exploring affordable AI solutions and fostering innovation in cost-effective AI technologies.
#
# **V. The Road Ahead: Strategies for Sustainable AI Growth in India (Offering Solutions - ~250 words)**
#
# *   **Strengthening AI Education and Skill Development:**
#     *   Promote AI education at all levels (schools, universities, vocational training).
#     *   Encourage collaboration between academia and industry to align training programs with industry needs.
#     *   Support online learning platforms and bootcamps for AI skills development.
# *   **Fostering Innovation and Entrepreneurship:**
#     *   Provide funding and mentorship to AI startups.
#     *   Encourage open-source AI development and collaboration.
#     *   Promote research and development in cutting-edge AI technologies.
# *   **Building a Robust Data Ecosystem:**
#     *   Develop data governance frameworks that balance data privacy with data accessibility.
#     *   Invest in data infrastructure and data standardization initiatives.
#     *   Encourage data sharing and collaboration between organizations.
# *   **Developing Ethical Guidelines and Regulatory Frameworks:**
#     *   Establish clear ethical principles for AI development and deployment.
#     *   Develop regulatory frameworks that address data privacy, algorithmic bias, and accountability.
#     *   Promote public awareness and understanding of AI ethics.
# *   **Prioritizing AI for Social Impact:**
#     *   Focus on developing AI solutions that address pressing social challenges such as poverty, healthcare, and education.
#     *   Ensure that AI technologies are accessible and beneficial to all segments of society.
#
# **VI. Conclusion (Summarizing & Inspiring - ~100 words)**
#
# *   **Recap:** Briefly summarize the key points discussed in the blog.
# *   **Reiterate Thesis:** Re-emphasize the importance of AI for India's future.
# *   **Call to Action:** Encourage readers to engage in the AI conversation, learn more about AI, and support initiatives that promote responsible AI development in India.  (e.g., "Stay informed about AI advancements in India and explore opportunities to contribute to this exciting technological revolution.").
